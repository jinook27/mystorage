# %% [markdown]
# # Load Data

# %%
import torch
import torchvision
import torchvision.transforms as transforms
torch.__version__
# Out:
# '1.6.0'

# %%
transform_train = transforms.Compose(
    [transforms.RandomHorizontalFlip(),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# transform_valid = transforms.Compose(
#     [transforms.ToTensor(),
#      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform_test = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

trainset = torchvision.datasets.CIFAR10(root='./data'
            ,train=True,download=True, transform=transform_train)

trainset2, validset = train_test_split(
                    trainset, test_size=0.2, random_state=0)
# validset = torchvision.datasets.CIFAR10(root='./data'
#             ,train=True, download=True, transform=transform_valid)

testset = torchvision.datasets.CIFAR10(root='./data'
            ,train=False,download=True, transform=transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
type(trainset)
# Out:
# torchvision.datasets.cifar.CIFAR10

# %%
type(trainset2)
# Out:
# list

# %%
trainloader = torch.utils.data.DataLoader(trainset2, batch_size=64,
                             shuffle=True, num_workers=0)

validloader = torch.utils.data.DataLoader(validset,batch_size=64,
                             shuffle=True, num_workers=0)

testloader = torch.utils.data.DataLoader(testset, batch_size=64,
                             shuffle=False, num_workers=0)

# %%
print('train:',type(trainloader), 'val:',type(validloader))
# Out:
# train: <class 'torch.utils.data.dataloader.DataLoader'> val: <class 'torch.utils.data.dataloader.DataLoader'>

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() 
                      else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Show sample images

# %%
import matplotlib.pyplot as plt
import numpy as np
# 이미지를 보여주기 위한 함수

def imshow(img):
    img = 0.5*img  + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# 학습용 이미지를 무작위로 가져오기
dataiter = iter(trainloader)
images, labels = dataiter.next()

# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# 정답(label) 출력
#print(' '.join('%5s' % classes[labels[j]] for j in range(4)))

# %% [markdown]
# # Define CNN

# %%
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler

def weights_init(m):
    if isinstance(m, nn.Conv2d):
        nn.init.xavier_normal(m.weight.data)
        torch.nn.init.ones_(m.bias.data)
        
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 5,stride=1,padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3,stride=1,padding=1) 
        self.conv3 = nn.Conv2d(64, 128, 3,stride=1,padding=1) 
        self.batchn1 = nn.BatchNorm2d(32)
        self.batchn2 = nn.BatchNorm2d(64)
        self.batchn3 = nn.BatchNorm2d(128)
        self.pool = nn.MaxPool2d(2, stride=2,padding=0) 
        self.dropout = nn.Dropout(0.5)
    
        self.fc1 = nn.Linear(128*3*3, 500)
        self.fc2 = nn.Linear(500,10)


    def forward(self, x):
        x = self.pool(F.relu(self.batchn1(self.conv1(x))))
        x = self.pool(F.relu(self.batchn2(self.conv2(x))))
        x = self.pool(F.relu(self.batchn3(self.conv3(x))))
        x = self.dropout(x)
        #x = self.pool(F.relu(self.dropout(self.conv1(x))))
        #x = self.pool(F.relu(self.dropout(self.conv2(x))))
        #x = self.pool(F.relu(self.dropout(self.conv3(x))))
        #print(x.shape)
        x = x.view(x.size(0),-1)
        
        x = self.dropout(self.fc1(x))
        x = self.dropout(self.fc2(x))
        return F.log_softmax(x,dim=1)

model=Model()
model.apply(weights_init)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: nn.init.xavier_normal is now deprecated in favor of nn.init.xavier_normal_.
#   if __name__ == '__main__':
# Model(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=1152, out_features=500, bias=True)
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
print("Model's state_dict:\n")
for param_tensor in model.state_dict():
    print(param_tensor, "\t ", model.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
#
# conv1.weight 	  torch.Size([32, 3, 5, 5])
# conv1.bias 	  torch.Size([32])
# conv2.weight 	  torch.Size([64, 32, 3, 3])
# conv2.bias 	  torch.Size([64])
# conv3.weight 	  torch.Size([128, 64, 3, 3])
# conv3.bias 	  torch.Size([128])
# batchn1.weight 	  torch.Size([32])
# batchn1.bias 	  torch.Size([32])
# batchn1.running_mean 	  torch.Size([32])
# batchn1.running_var 	  torch.Size([32])
# batchn1.num_batches_tracked 	  torch.Size([])
# batchn2.weight 	  torch.Size([64])
# batchn2.bias 	  torch.Size([64])
# batchn2.running_mean 	  torch.Size([64])
# batchn2.running_var 	  torch.Size([64])
# batchn2.num_batches_tracked 	  torch.Size([])
# batchn3.weight 	  torch.Size([128])
# batchn3.bias 	  torch.Size([128])
# batchn3.running_mean 	  torch.Size([128])
# batchn3.running_var 	  torch.Size([128])
# batchn3.num_batches_tracked 	  torch.Size([])
# fc1.weight 	  torch.Size([500, 1152])
# fc1.bias 	  torch.Size([500])
# fc2.weight 	  torch.Size([10, 500])
# fc2.bias 	  torch.Size([10])

# %%
from torchsummary import summary
summary(model.to(device), (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]           2,432
#        BatchNorm2d-2           [-1, 32, 30, 30]              64
#          MaxPool2d-3           [-1, 32, 15, 15]               0
#             Conv2d-4           [-1, 64, 15, 15]          18,496
#        BatchNorm2d-5           [-1, 64, 15, 15]             128
#          MaxPool2d-6             [-1, 64, 7, 7]               0
#             Conv2d-7            [-1, 128, 7, 7]          73,856
#        BatchNorm2d-8            [-1, 128, 7, 7]             256
#          MaxPool2d-9            [-1, 128, 3, 3]               0
#           Dropout-10            [-1, 128, 3, 3]               0
#            Linear-11                  [-1, 500]         576,500
#           Dropout-12                  [-1, 500]               0
#            Linear-13                   [-1, 10]           5,010
#           Dropout-14                   [-1, 10]               0
# ================================================================
# Total params: 676,742
# Trainable params: 676,742
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.86
# Params size (MB): 2.58
# Estimated Total Size (MB): 3.45
# ----------------------------------------------------------------

# %% [markdown]
# # Loss & Optimizer

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.001)

scheduler = optim.lr_scheduler.MultiStepLR(optimizer=optimizer,
                milestones=[2,5, 10, 11, 28, 33], gamma=0.5)

# %%
type(trainloader)
# Out:
# torch.utils.data.dataloader.DataLoader

# %%
type(validloader)
# Out:
# torch.utils.data.dataloader.DataLoader

# %% [markdown]
# # Train & Validation

# %%
train_loss=[]
train_acc=[]
val_loss=[]
val_acc=[]

num_epochs = 200

model.to(device)
for epoch in range(num_epochs):
    print('epoch : ',epoch+1)
    model.train() 
    for i, data in enumerate(trainloader, 0):

        inputs = data[0].to(device)
        labels = data[1].to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        scheduler.step()
        
    model.eval()  
    with torch.no_grad():
        running_loss = 0.0
        corrects = 0.0
        total = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs = data[0].to(device)
            labels = data[1].to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            total += labels.size(0)
            corrects += (preds == labels).sum().item()

        epoch_loss = running_loss / i
        epoch_acc = 100*corrects/total
        train_loss.append(epoch_loss)
        train_acc.append(100*corrects/total)
        print('-' * 10)
        print('train: Loss: {:.4f} Acc: {:.4f}'.format(
            epoch_loss, epoch_acc))
        
        running_loss = 0.0
        corrects = 0.0
        total = 0.0
        for i, data in enumerate(validloader, 0):
            inputs = data[0].to(device)
            labels = data[1].to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            total += labels.size(0)
            corrects += (preds == labels).sum().item()  

        epoch_loss = running_loss / i
        epoch_acc = 100*corrects/total
        val_loss.append(epoch_loss)
        val_acc.append(epoch_acc)

        print('valid:  Loss: {:.4f} Acc: {:.4f}'.format(
        epoch_loss, epoch_acc))
        print('-' * 10,'\n')
# Out:
# epoch :  1
# ----------
# train: Loss: 1.8603 Acc: 39.9350
# valid:  Loss: 1.8681 Acc: 39.5000
# ----------
#
# epoch :  2
# ----------
# train: Loss: 1.7686 Acc: 43.8025
# valid:  Loss: 1.7777 Acc: 42.9900
# ----------
#
# epoch :  3
# ----------
# train: Loss: 1.7136 Acc: 47.0225
# valid:  Loss: 1.7246 Acc: 46.0800
# ----------
#
# epoch :  4
# ----------
# train: Loss: 1.6733 Acc: 48.1200
# valid:  Loss: 1.6864 Acc: 47.2500
# ----------
#
# epoch :  5
# ----------
# train: Loss: 1.6283 Acc: 50.4425
# valid:  Loss: 1.6412 Acc: 49.7800
# ----------
#
# epoch :  6
# ----------
# train: Loss: 1.6009 Acc: 51.7575
# valid:  Loss: 1.6138 Acc: 50.7800
# ----------
#
# epoch :  7
# ----------
# train: Loss: 1.5717 Acc: 52.9775
# valid:  Loss: 1.5868 Acc: 51.8600
# ----------
#
# epoch :  8
# ----------
# train: Loss: 1.5460 Acc: 54.3650
# valid:  Loss: 1.5618 Acc: 53.4900
# ----------
#
# epoch :  9
# ----------
# train: Loss: 1.5242 Acc: 55.1150
# valid:  Loss: 1.5407 Acc: 54.1800
# ----------
#
# epoch :  10
# ----------
# train: Loss: 1.5048 Acc: 55.7800
# valid:  Loss: 1.5245 Acc: 54.7100
# ----------
#
# epoch :  11
# ----------
# train: Loss: 1.4882 Acc: 56.7200
# valid:  Loss: 1.5097 Acc: 55.5400
# ----------
#
# epoch :  12
# ----------
# train: Loss: 1.4665 Acc: 57.4175
# valid:  Loss: 1.4886 Acc: 56.1000
# ----------
#
# epoch :  13
# ----------
# train: Loss: 1.4440 Acc: 58.6275
# valid:  Loss: 1.4669 Acc: 57.1000
# ----------
#
# epoch :  14
# ----------
# train: Loss: 1.4282 Acc: 59.2475
# valid:  Loss: 1.4532 Acc: 57.2800
# ----------
#
# epoch :  15
# ----------
# train: Loss: 1.4154 Acc: 59.4500
# valid:  Loss: 1.4404 Acc: 57.9700
# ----------
#
# epoch :  16
# ----------
# train: Loss: 1.3970 Acc: 60.1825
# valid:  Loss: 1.4237 Acc: 58.7000
# ----------
#
# epoch :  17
# ----------
# train: Loss: 1.3860 Acc: 60.7875
# valid:  Loss: 1.4129 Acc: 59.0600
# ----------
#
# epoch :  18
# ----------
# train: Loss: 1.3747 Acc: 61.0200
# valid:  Loss: 1.4038 Acc: 59.4500
# ----------
#
# epoch :  19
# ----------
# train: Loss: 1.3651 Acc: 61.6525
# valid:  Loss: 1.3939 Acc: 59.7800
# ----------
#
# epoch :  20
# ----------
# train: Loss: 1.3446 Acc: 61.7275
# valid:  Loss: 1.3759 Acc: 59.8700
# ----------
#
# epoch :  21
# ----------
# train: Loss: 1.3342 Acc: 62.6100
# valid:  Loss: 1.3658 Acc: 60.7200
# ----------
#
# epoch :  22
# ----------
# train: Loss: 1.3220 Acc: 62.7325
# valid:  Loss: 1.3535 Acc: 61.0400
# ----------
#
# epoch :  23
# ----------
# train: Loss: 1.3144 Acc: 63.3575
# valid:  Loss: 1.3476 Acc: 60.8800
# ----------
#
# epoch :  24
# ----------
# train: Loss: 1.3027 Acc: 63.7275
# valid:  Loss: 1.3364 Acc: 61.4100
# ----------
#
# epoch :  25
# ----------
# train: Loss: 1.2939 Acc: 64.3200
# valid:  Loss: 1.3282 Acc: 62.2100
# ----------
#
# epoch :  26
# ----------
# train: Loss: 1.2829 Acc: 64.3100
# valid:  Loss: 1.3203 Acc: 62.1500
# ----------
#
# epoch :  27
# ----------
# train: Loss: 1.2747 Acc: 64.7400
# valid:  Loss: 1.3117 Acc: 62.4100
# ----------
#
# epoch :  28
# ----------
# train: Loss: 1.2643 Acc: 65.2275
# valid:  Loss: 1.3036 Acc: 62.5000
# ----------
#
# epoch :  29
# ----------
# train: Loss: 1.2564 Acc: 65.4050
# valid:  Loss: 1.2946 Acc: 63.0800
# ----------
#
# epoch :  30
# ----------
# train: Loss: 1.2440 Acc: 65.6400
# valid:  Loss: 1.2830 Acc: 62.9800
# ----------
#
# epoch :  31
# ----------
# train: Loss: 1.2379 Acc: 65.7400
# valid:  Loss: 1.2785 Acc: 63.4000
# ----------
#
# epoch :  32
# ----------
# train: Loss: 1.2343 Acc: 66.4275
# valid:  Loss: 1.2768 Acc: 63.8100
# ----------
#
# epoch :  33
# ----------
# train: Loss: 1.2260 Acc: 66.7700
# valid:  Loss: 1.2687 Acc: 64.3100
# ----------
#
# epoch :  34
# ----------
# train: Loss: 1.2092 Acc: 67.0300
# valid:  Loss: 1.2515 Acc: 64.2900
# ----------
#
# epoch :  35
# ----------
# train: Loss: 1.2075 Acc: 67.1750
# valid:  Loss: 1.2513 Acc: 64.6100
# ----------
#
# epoch :  36
# ----------
# train: Loss: 1.2001 Acc: 67.2625
# valid:  Loss: 1.2467 Acc: 64.7000
# ----------
#
# epoch :  37
# ----------
# train: Loss: 1.1942 Acc: 67.6050
# valid:  Loss: 1.2407 Acc: 64.7500
# ----------
#
# epoch :  38
# ----------
# train: Loss: 1.1853 Acc: 67.7825
# valid:  Loss: 1.2321 Acc: 65.0900
# ----------
#
# epoch :  39
# ----------
# train: Loss: 1.1733 Acc: 68.0600
# valid:  Loss: 1.2222 Acc: 65.2900
# ----------
#
# epoch :  40
# ----------
# train: Loss: 1.1714 Acc: 68.3100
# valid:  Loss: 1.2213 Acc: 65.3500
# ----------
#
# epoch :  41
# ----------
# train: Loss: 1.1623 Acc: 68.5700
# valid:  Loss: 1.2100 Acc: 65.4000
# ----------
#
# epoch :  42
# ----------
# train: Loss: 1.1544 Acc: 68.7775
# valid:  Loss: 1.2062 Acc: 65.5100
# ----------
#
# epoch :  43
# ----------
# train: Loss: 1.1513 Acc: 69.1325
# valid:  Loss: 1.2027 Acc: 65.9700
# ----------
#
# epoch :  44
# ----------
# train: Loss: 1.1411 Acc: 68.9250
# valid:  Loss: 1.1941 Acc: 65.8900
# ----------
#
# epoch :  45
# ----------
# train: Loss: 1.1424 Acc: 69.2400
# valid:  Loss: 1.1939 Acc: 65.9000
# ----------
#
# epoch :  46
# ----------
# train: Loss: 1.1325 Acc: 69.5975
# valid:  Loss: 1.1872 Acc: 66.2200
# ----------
#
# epoch :  47
# ----------
# train: Loss: 1.1227 Acc: 69.6875
# valid:  Loss: 1.1777 Acc: 66.4600
# ----------
#
# epoch :  48
# ----------
# train: Loss: 1.1184 Acc: 69.7825
# valid:  Loss: 1.1735 Acc: 66.5900
# ----------
#
# epoch :  49
# ----------
# train: Loss: 1.1151 Acc: 70.1575
# valid:  Loss: 1.1712 Acc: 66.7200
# ----------
#
# epoch :  50
# ----------
# train: Loss: 1.1132 Acc: 70.4900
# valid:  Loss: 1.1698 Acc: 66.8600
# ----------
#
# epoch :  51
# ----------
# train: Loss: 1.0970 Acc: 70.6400
# valid:  Loss: 1.1526 Acc: 67.3300
# ----------
#
# epoch :  52
# ----------
# train: Loss: 1.1004 Acc: 70.9750
# valid:  Loss: 1.1594 Acc: 67.3800
# ----------
#
# epoch :  53
# ----------
# train: Loss: 1.0918 Acc: 71.0425
# valid:  Loss: 1.1510 Acc: 67.2200
# ----------
#
# epoch :  54
# ----------
# train: Loss: 1.0887 Acc: 71.3350
# valid:  Loss: 1.1479 Acc: 67.7900
# ----------
#
# epoch :  55
# ----------
# train: Loss: 1.0820 Acc: 71.3650
# valid:  Loss: 1.1447 Acc: 67.5800
# ----------
#
# epoch :  56
# ----------
# train: Loss: 1.0747 Acc: 71.4625
# valid:  Loss: 1.1375 Acc: 67.6300
# ----------
#
# epoch :  57
# ----------
# train: Loss: 1.0671 Acc: 71.6900
# valid:  Loss: 1.1294 Acc: 68.0800
# ----------
#
# epoch :  58
# ----------
# train: Loss: 1.0663 Acc: 71.9825
# valid:  Loss: 1.1301 Acc: 68.1200
# ----------
#
# epoch :  59
# ----------
# train: Loss: 1.0581 Acc: 71.8375
# valid:  Loss: 1.1232 Acc: 68.1500
# ----------
#
# epoch :  60
# ----------
# train: Loss: 1.0542 Acc: 72.0875
# valid:  Loss: 1.1210 Acc: 68.4400
# ----------
#
# epoch :  61
# ----------
# train: Loss: 1.0547 Acc: 72.3800
# valid:  Loss: 1.1204 Acc: 68.5400
# ----------
#
# epoch :  62
# ----------
# train: Loss: 1.0483 Acc: 72.1925
# valid:  Loss: 1.1159 Acc: 68.2400
# ----------
#
# epoch :  63
# ----------
# train: Loss: 1.0426 Acc: 72.6225
# valid:  Loss: 1.1127 Acc: 68.6700
# ----------
#
# epoch :  64
# ----------
# train: Loss: 1.0376 Acc: 73.0025
# valid:  Loss: 1.1056 Acc: 68.7300
# ----------
#
# epoch :  65
# ----------
# train: Loss: 1.0382 Acc: 73.0700
# valid:  Loss: 1.1077 Acc: 68.9200
# ----------
#
# epoch :  66
# ----------
# train: Loss: 1.0264 Acc: 73.1700
# valid:  Loss: 1.0966 Acc: 68.8000
# ----------
#
# epoch :  67
# ----------
# train: Loss: 1.0296 Acc: 73.1150
# valid:  Loss: 1.0995 Acc: 69.0700
# ----------
#
# epoch :  68
# ----------
# train: Loss: 1.0257 Acc: 73.2700
# valid:  Loss: 1.0949 Acc: 68.9800
# ----------
#
# epoch :  69
# ----------
# train: Loss: 1.0221 Acc: 73.5225
# valid:  Loss: 1.0951 Acc: 69.1000
# ----------
#
# epoch :  70
# ----------
# train: Loss: 1.0128 Acc: 73.5950
# valid:  Loss: 1.0857 Acc: 69.4800
# ----------
#
# epoch :  71
# ----------
# train: Loss: 1.0045 Acc: 73.7325
# valid:  Loss: 1.0795 Acc: 69.4900
# ----------
#
# epoch :  72
# ----------
# train: Loss: 1.0033 Acc: 74.0375
# valid:  Loss: 1.0770 Acc: 69.6700
# ----------
#
# epoch :  73
# ----------
# train: Loss: 1.0018 Acc: 74.2150
# valid:  Loss: 1.0770 Acc: 69.8700
# ----------
#
# epoch :  74
# ----------
# train: Loss: 0.9952 Acc: 74.2400
# valid:  Loss: 1.0705 Acc: 69.8100
# ----------
#
# epoch :  75
# ----------
# train: Loss: 0.9907 Acc: 74.3675
# valid:  Loss: 1.0655 Acc: 69.8400
# ----------
#
# epoch :  76
# ----------
# train: Loss: 0.9923 Acc: 74.4075
# valid:  Loss: 1.0691 Acc: 70.0800
# ----------
#
# epoch :  77
# ----------
# train: Loss: 0.9860 Acc: 74.7250
# valid:  Loss: 1.0641 Acc: 70.1900
# ----------
#
# epoch :  78
# ----------
# train: Loss: 0.9815 Acc: 74.6975
# valid:  Loss: 1.0625 Acc: 69.7800
# ----------
#
# epoch :  79
# ----------
# train: Loss: 0.9765 Acc: 74.8200
# valid:  Loss: 1.0545 Acc: 70.2600
# ----------
#
# epoch :  80
# ----------
# train: Loss: 0.9758 Acc: 75.0025
# valid:  Loss: 1.0575 Acc: 70.2000
# ----------
#
# epoch :  81
# ----------
# train: Loss: 0.9678 Acc: 74.7925
# valid:  Loss: 1.0468 Acc: 69.9400
# ----------
#
# epoch :  82
# ----------
# train: Loss: 0.9640 Acc: 75.2325
# valid:  Loss: 1.0474 Acc: 70.4200
# ----------
#
# epoch :  83
# ----------
# train: Loss: 0.9612 Acc: 75.1350
# valid:  Loss: 1.0445 Acc: 69.9700
# ----------
#
# epoch :  84
# ----------
# train: Loss: 0.9568 Acc: 75.1350
# valid:  Loss: 1.0404 Acc: 69.8900
# ----------
#
# epoch :  85
# ----------
# train: Loss: 0.9572 Acc: 75.5800
# valid:  Loss: 1.0399 Acc: 70.6300
# ----------
#
# epoch :  86
# ----------
# train: Loss: 0.9474 Acc: 75.5950
# valid:  Loss: 1.0335 Acc: 70.2900
# ----------
#
# epoch :  87
# ----------
# train: Loss: 0.9440 Acc: 75.6725
# valid:  Loss: 1.0307 Acc: 70.3300
# ----------
#
# epoch :  88
# ----------
# train: Loss: 0.9417 Acc: 75.7450
# valid:  Loss: 1.0289 Acc: 70.5300
# ----------
#
# epoch :  89
# ----------
# train: Loss: 0.9398 Acc: 75.8600
# valid:  Loss: 1.0290 Acc: 70.8500
# ----------
#
# epoch :  90
# ----------
# train: Loss: 0.9361 Acc: 76.2350
# valid:  Loss: 1.0264 Acc: 70.8500
# ----------
#
# epoch :  91
# ----------
# train: Loss: 0.9329 Acc: 76.3425
# valid:  Loss: 1.0217 Acc: 70.9400
# ----------
#
# epoch :  92
# ----------
# train: Loss: 0.9256 Acc: 76.1050
# valid:  Loss: 1.0161 Acc: 71.1600
# ----------
#
# epoch :  93
# ----------
# train: Loss: 0.9275 Acc: 76.3475
# valid:  Loss: 1.0193 Acc: 71.0700
# ----------
#
# epoch :  94
# ----------
# train: Loss: 0.9200 Acc: 76.5425
# valid:  Loss: 1.0116 Acc: 71.1500
# ----------
#
# epoch :  95
# ----------
# train: Loss: 0.9218 Acc: 76.5675
# valid:  Loss: 1.0167 Acc: 70.8600
# ----------
#
# epoch :  96
# ----------
# train: Loss: 0.9086 Acc: 76.8525
# valid:  Loss: 1.0028 Acc: 71.0900
# ----------
#
# epoch :  97
# ----------
# train: Loss: 0.9157 Acc: 76.7375
# valid:  Loss: 1.0108 Acc: 71.2400
# ----------
#
# epoch :  98
# ----------
# train: Loss: 0.9107 Acc: 76.9525
# valid:  Loss: 1.0077 Acc: 71.2800
# ----------
#
# epoch :  99
# ----------
# train: Loss: 0.9129 Acc: 77.1025
# valid:  Loss: 1.0090 Acc: 71.4700
# ----------
#
# epoch :  100
# ----------
# train: Loss: 0.9043 Acc: 77.1200
# valid:  Loss: 1.0030 Acc: 71.5300
# ----------
#
# epoch :  101
# ----------
# train: Loss: 0.9072 Acc: 77.2100
# valid:  Loss: 1.0034 Acc: 71.5800
# ----------
#
# epoch :  102
# ----------
# train: Loss: 0.8983 Acc: 77.1100
# valid:  Loss: 0.9978 Acc: 71.2100
# ----------
#
# epoch :  103
# ----------
# train: Loss: 0.8995 Acc: 77.2425
# valid:  Loss: 1.0005 Acc: 71.4400
# ----------
#
# epoch :  104
# ----------
# train: Loss: 0.8892 Acc: 77.2950
# valid:  Loss: 0.9880 Acc: 71.3700
# ----------
#
# epoch :  105
# ----------
# train: Loss: 0.8928 Acc: 77.5325
# valid:  Loss: 0.9949 Acc: 71.4800
# ----------
#
# epoch :  106
# ----------
# train: Loss: 0.8816 Acc: 77.5825
# valid:  Loss: 0.9840 Acc: 71.4300
# ----------
#
# epoch :  107
# ----------
# train: Loss: 0.8846 Acc: 77.4850
# valid:  Loss: 0.9873 Acc: 71.4600
# ----------
#
# epoch :  108
# ----------
# train: Loss: 0.8831 Acc: 77.7100
# valid:  Loss: 0.9874 Acc: 71.6900
# ----------
#
# epoch :  109
# ----------
# train: Loss: 0.8797 Acc: 77.8150
# valid:  Loss: 0.9847 Acc: 71.6100
# ----------
#
# epoch :  110
# ----------
# train: Loss: 0.8729 Acc: 77.9825
# valid:  Loss: 0.9777 Acc: 71.7700
# ----------
#
# epoch :  111
# ----------
# train: Loss: 0.8730 Acc: 78.0975
# valid:  Loss: 0.9806 Acc: 71.6000
# ----------
#
# epoch :  112
# ----------
# train: Loss: 0.8767 Acc: 78.2675
# valid:  Loss: 0.9843 Acc: 71.7900
# ----------
#
# epoch :  113
# ----------
# train: Loss: 0.8694 Acc: 78.3250
# valid:  Loss: 0.9771 Acc: 71.8000
# ----------
#
# epoch :  114
# ----------
# train: Loss: 0.8694 Acc: 78.3275
# valid:  Loss: 0.9772 Acc: 71.9000
# ----------
#
# epoch :  115
# ----------
# train: Loss: 0.8650 Acc: 78.4000
# valid:  Loss: 0.9762 Acc: 71.7600
# ----------
#
# epoch :  116
# ----------
# train: Loss: 0.8571 Acc: 78.4500
# valid:  Loss: 0.9685 Acc: 71.6300
# ----------
#
# epoch :  117
# ----------
# train: Loss: 0.8580 Acc: 78.6850
# valid:  Loss: 0.9707 Acc: 72.0300
# ----------
#
# epoch :  118
# ----------
# train: Loss: 0.8519 Acc: 78.7525
# valid:  Loss: 0.9656 Acc: 72.1300
# ----------
#
# epoch :  119
# ----------
# train: Loss: 0.8502 Acc: 78.7350
# valid:  Loss: 0.9648 Acc: 72.2200
# ----------
#
# epoch :  120
# ----------
# train: Loss: 0.8492 Acc: 78.6825
# valid:  Loss: 0.9620 Acc: 72.3400
# ----------
#
# epoch :  121
# ----------
# train: Loss: 0.8462 Acc: 79.0375
# valid:  Loss: 0.9612 Acc: 72.2900
# ----------
#
# epoch :  122
# ----------
# train: Loss: 0.8455 Acc: 79.0425
# valid:  Loss: 0.9592 Acc: 72.4800
# ----------
#
# epoch :  123
# ----------
# train: Loss: 0.8347 Acc: 79.0250
# valid:  Loss: 0.9518 Acc: 72.4100
# ----------
#
# epoch :  124
# ----------
# train: Loss: 0.8403 Acc: 79.3925
# valid:  Loss: 0.9586 Acc: 72.4200
# ----------
#
# epoch :  125
# ----------
# train: Loss: 0.8425 Acc: 79.3725
# valid:  Loss: 0.9604 Acc: 72.3300
# ----------
#
# epoch :  126
# ----------
# train: Loss: 0.8320 Acc: 79.5800
# valid:  Loss: 0.9516 Acc: 72.4300
# ----------
#
# epoch :  127
# ----------
# train: Loss: 0.8313 Acc: 79.5150
# valid:  Loss: 0.9489 Acc: 72.5000
# ----------
#
# epoch :  128
# ----------
# train: Loss: 0.8262 Acc: 79.5275
# valid:  Loss: 0.9466 Acc: 72.6600
# ----------
#
# epoch :  129
# ----------
# train: Loss: 0.8257 Acc: 79.6450
# valid:  Loss: 0.9467 Acc: 72.6800
# ----------
#
# epoch :  130
# ----------
# train: Loss: 0.8246 Acc: 79.6925
# valid:  Loss: 0.9473 Acc: 72.5200
# ----------
#
# epoch :  131
# ----------
# train: Loss: 0.8254 Acc: 79.9325
# valid:  Loss: 0.9462 Acc: 72.8100
# ----------
#
# epoch :  132
# ----------
# train: Loss: 0.8227 Acc: 79.6950
# valid:  Loss: 0.9459 Acc: 72.5500
# ----------
#
# epoch :  133
# ----------
# train: Loss: 0.8155 Acc: 79.9275
# valid:  Loss: 0.9399 Acc: 72.7600
# ----------
#
# epoch :  134
# ----------
# train: Loss: 0.8143 Acc: 80.0825
# valid:  Loss: 0.9404 Acc: 72.6500
# ----------
#
# epoch :  135
# ----------
# train: Loss: 0.8109 Acc: 79.9625
# valid:  Loss: 0.9370 Acc: 72.7200
# ----------
#
# epoch :  136
# ----------
# train: Loss: 0.8075 Acc: 80.2300
# valid:  Loss: 0.9343 Acc: 72.9200
# ----------
#
# epoch :  137
# ----------
# train: Loss: 0.8069 Acc: 80.1975
# valid:  Loss: 0.9329 Acc: 72.9200
# ----------
#
# epoch :  138
# ----------
# train: Loss: 0.8014 Acc: 80.2750
# valid:  Loss: 0.9318 Acc: 72.7200
# ----------
#
# epoch :  139
# ----------
# train: Loss: 0.8000 Acc: 80.5175
# valid:  Loss: 0.9304 Acc: 72.9600
# ----------
#
# epoch :  140
# ----------
# train: Loss: 0.7961 Acc: 80.4650
# valid:  Loss: 0.9265 Acc: 72.7700
# ----------
#
# epoch :  141
# ----------
# train: Loss: 0.7980 Acc: 80.4450
# valid:  Loss: 0.9288 Acc: 72.9600
# ----------
#
# epoch :  142
# ----------
# train: Loss: 0.7941 Acc: 80.5300
# valid:  Loss: 0.9304 Acc: 72.7300
# ----------
#
# epoch :  143
# ----------
# train: Loss: 0.7954 Acc: 80.7100
# valid:  Loss: 0.9267 Acc: 73.2000
# ----------
#
# epoch :  144
# ----------
# train: Loss: 0.7913 Acc: 80.9325
# valid:  Loss: 0.9240 Acc: 73.3100
# ----------
#
# epoch :  145
# ----------
# train: Loss: 0.7881 Acc: 80.8850
# valid:  Loss: 0.9213 Acc: 73.2500
# ----------
#
# epoch :  146
# ----------
# train: Loss: 0.7822 Acc: 80.8275
# valid:  Loss: 0.9181 Acc: 73.0800
# ----------
#
# epoch :  147
# ----------
# train: Loss: 0.7773 Acc: 80.9875
# valid:  Loss: 0.9148 Acc: 73.2600
# ----------
#
# epoch :  148
# ----------
# train: Loss: 0.7793 Acc: 81.0000
# valid:  Loss: 0.9154 Acc: 73.2700
# ----------
#
# epoch :  149
# ----------
# train: Loss: 0.7762 Acc: 80.7775
# valid:  Loss: 0.9127 Acc: 73.2400
# ----------
#
# epoch :  150
# ----------
# train: Loss: 0.7750 Acc: 81.2325
# valid:  Loss: 0.9147 Acc: 73.4400
# ----------
#
# epoch :  151
# ----------
# train: Loss: 0.7730 Acc: 81.1050
# valid:  Loss: 0.9141 Acc: 73.1600
# ----------
#
# epoch :  152
# ----------
# train: Loss: 0.7668 Acc: 81.4700
# valid:  Loss: 0.9066 Acc: 73.4700
# ----------
#
# epoch :  153
# ----------
# train: Loss: 0.7723 Acc: 81.5150
# valid:  Loss: 0.9115 Acc: 73.3800
# ----------
#
# epoch :  154
# ----------
# train: Loss: 0.7649 Acc: 81.5300
# valid:  Loss: 0.9050 Acc: 73.3700
# ----------
#
# epoch :  155
# ----------
# train: Loss: 0.7634 Acc: 81.5100
# valid:  Loss: 0.9037 Acc: 73.5100
# ----------
#
# epoch :  156
# ----------
# train: Loss: 0.7609 Acc: 81.7500
# valid:  Loss: 0.9044 Acc: 73.4700
# ----------
#
# epoch :  157
# ----------
# train: Loss: 0.7556 Acc: 81.7575
# valid:  Loss: 0.8988 Acc: 73.3900
# ----------
#
# epoch :  158
# ----------
# train: Loss: 0.7625 Acc: 81.9275
# valid:  Loss: 0.9054 Acc: 73.5100
# ----------
#
# epoch :  159
# ----------
# train: Loss: 0.7521 Acc: 81.8975
# valid:  Loss: 0.8975 Acc: 73.7100
# ----------
#
# epoch :  160
# ----------
# train: Loss: 0.7556 Acc: 82.1325
# valid:  Loss: 0.9023 Acc: 73.8600
# ----------
#
# epoch :  161
# ----------
# train: Loss: 0.7564 Acc: 81.9400
# valid:  Loss: 0.9031 Acc: 73.4100
# ----------
#
# epoch :  162
# ----------
# train: Loss: 0.7509 Acc: 82.0075
# valid:  Loss: 0.9003 Acc: 73.4200
# ----------
#
# epoch :  163
# ----------
# train: Loss: 0.7437 Acc: 81.8650
# valid:  Loss: 0.8947 Acc: 73.5400
# ----------
#
# epoch :  164
# ----------
# train: Loss: 0.7476 Acc: 82.3200
# valid:  Loss: 0.8985 Acc: 73.5100
# ----------
#
# epoch :  165
# ----------
# train: Loss: 0.7473 Acc: 82.4850
# valid:  Loss: 0.8986 Acc: 73.7100
# ----------
#
# epoch :  166
# ----------
# train: Loss: 0.7392 Acc: 82.2500
# valid:  Loss: 0.8905 Acc: 73.7100
# ----------
#
# epoch :  167
# ----------
# train: Loss: 0.7379 Acc: 82.4775
# valid:  Loss: 0.8896 Acc: 73.7100
# ----------
#
# epoch :  168
# ----------
# train: Loss: 0.7411 Acc: 82.3175
# valid:  Loss: 0.8940 Acc: 73.6100
# ----------
#
# epoch :  169
# ----------
# train: Loss: 0.7340 Acc: 82.5900
# valid:  Loss: 0.8874 Acc: 73.7900
# ----------
#
# epoch :  170
# ----------
# train: Loss: 0.7296 Acc: 82.6250
# valid:  Loss: 0.8843 Acc: 73.8900
# ----------
#
# epoch :  171
# ----------
# train: Loss: 0.7301 Acc: 82.5675
# valid:  Loss: 0.8876 Acc: 73.5500
# ----------
#
# epoch :  172
# ----------
# train: Loss: 0.7304 Acc: 82.6250
# valid:  Loss: 0.8894 Acc: 73.7000
# ----------
#
# epoch :  173
# ----------
# train: Loss: 0.7329 Acc: 82.6550
# valid:  Loss: 0.8895 Acc: 73.8700
# ----------
#
# epoch :  174
# ----------
# train: Loss: 0.7228 Acc: 82.7875
# valid:  Loss: 0.8822 Acc: 73.6600
# ----------
#
# epoch :  175
# ----------
# train: Loss: 0.7239 Acc: 82.8150
# valid:  Loss: 0.8853 Acc: 73.8100
# ----------
#
# epoch :  176
# ----------
# train: Loss: 0.7203 Acc: 83.1000
# valid:  Loss: 0.8800 Acc: 74.0100
# ----------
#
# epoch :  177
# ----------
# train: Loss: 0.7194 Acc: 83.0600
# valid:  Loss: 0.8808 Acc: 73.7200
# ----------
#
# epoch :  178
# ----------
# train: Loss: 0.7180 Acc: 83.0800
# valid:  Loss: 0.8790 Acc: 73.8500
# ----------
#
# epoch :  179
# ----------
# train: Loss: 0.7173 Acc: 83.3100
# valid:  Loss: 0.8807 Acc: 73.9200
# ----------
#
# epoch :  180
# ----------
# train: Loss: 0.7141 Acc: 83.1425
# valid:  Loss: 0.8762 Acc: 73.9200
# ----------
#
# epoch :  181
# ----------
# train: Loss: 0.7138 Acc: 83.3125
# valid:  Loss: 0.8791 Acc: 74.1300
# ----------
#
# epoch :  182
# ----------
# train: Loss: 0.7045 Acc: 83.2275
# valid:  Loss: 0.8708 Acc: 74.0700
# ----------
#
# epoch :  183
# ----------
# train: Loss: 0.7092 Acc: 83.4200
# valid:  Loss: 0.8736 Acc: 74.1400
# ----------
#
# epoch :  184
# ----------
# train: Loss: 0.7082 Acc: 83.4375
# valid:  Loss: 0.8746 Acc: 74.0200
# ----------
#
# epoch :  185
# ----------
# train: Loss: 0.7062 Acc: 83.3275
# valid:  Loss: 0.8749 Acc: 73.8000
# ----------
#
# epoch :  186
# ----------
# train: Loss: 0.7039 Acc: 83.5775
# valid:  Loss: 0.8733 Acc: 74.1300
# ----------
#
# epoch :  187
# ----------
# train: Loss: 0.7084 Acc: 83.5350
# valid:  Loss: 0.8766 Acc: 74.1600
# ----------
#
# epoch :  188
# ----------
# train: Loss: 0.7040 Acc: 83.7675
# valid:  Loss: 0.8739 Acc: 73.9700
# ----------
#
# epoch :  189
# ----------
# train: Loss: 0.6963 Acc: 83.8600
# valid:  Loss: 0.8688 Acc: 73.9700
# ----------
#
# epoch :  190
# ----------
# train: Loss: 0.6925 Acc: 84.1025
# valid:  Loss: 0.8665 Acc: 73.9700
# ----------
#
# epoch :  191
# ----------
# train: Loss: 0.6928 Acc: 84.0725
# valid:  Loss: 0.8661 Acc: 74.0800
# ----------
#
# epoch :  192
# ----------
# train: Loss: 0.6893 Acc: 83.9425
# valid:  Loss: 0.8626 Acc: 74.1300
# ----------
#
# epoch :  193
# ----------
# train: Loss: 0.6880 Acc: 83.8300
# valid:  Loss: 0.8618 Acc: 73.9700
# ----------
#
# epoch :  194
# ----------
# train: Loss: 0.6915 Acc: 84.1350
# valid:  Loss: 0.8677 Acc: 74.1200
# ----------
#
# epoch :  195
# ----------
# train: Loss: 0.6869 Acc: 84.2775
# valid:  Loss: 0.8652 Acc: 74.0700
# ----------
#
# epoch :  196
# ----------
# train: Loss: 0.6823 Acc: 84.0825
# valid:  Loss: 0.8617 Acc: 73.8700
# ----------
#
# epoch :  197
# ----------
# train: Loss: 0.6869 Acc: 84.4750
# valid:  Loss: 0.8659 Acc: 74.4500
# ----------
#
# epoch :  198
# ----------
# train: Loss: 0.6838 Acc: 84.5100
# valid:  Loss: 0.8633 Acc: 74.2300
# ----------
#
# epoch :  199
# ----------
# train: Loss: 0.6797 Acc: 84.4575
# valid:  Loss: 0.8590 Acc: 74.1700
# ----------
#
# epoch :  200
# ----------
# train: Loss: 0.6778 Acc: 84.4900
# valid:  Loss: 0.8570 Acc: 74.4600
# ----------

# %%
# blue for train
# darkgreen for validation
# crimson for test

# %%
x_axis = range(1,num_epochs+1)

#plot loss
plt.plot(x_axis,train_loss,'blue')
plt.plot(x_axis,val_loss,'darkgreen') 
plt.legend(('train', 'valid'),loc='upper right')
plt.title('customized CNN')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

#plot accuracy
plt.plot(x_axis,train_acc,'blue')
plt.plot(x_axis,val_acc,'darkgreen')
plt.legend(('train', 'valid'),loc='upper left')
plt.title('customized CNN')
plt.xlabel('epoch')
plt.ylabel('accurarcy')
plt.show()

# %% [markdown]
# # Train & Test

# %%
train_loss=[]
train_acc=[]
test_loss=[]
test_acc=[]

num_epochs = 200

model.to(device)
for epoch in range(num_epochs):
    print('epoch : ',epoch+1)
    model.train() 
    for i, data in enumerate(trainloader, 0):

        inputs = data[0].to(device)
        labels = data[1].to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        scheduler.step()
        
    model.eval()  
    with torch.no_grad():
        running_loss = 0.0
        corrects = 0.0
        total = 0.0
        for i, data in enumerate(trainloader, 0):
            inputs = data[0].to(device)
            labels = data[1].to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            total += labels.size(0)
            corrects += (preds == labels).sum().item()

        epoch_loss = running_loss / i
        epoch_acc = 100*corrects/total
        train_loss.append(epoch_loss)
        train_acc.append(100*corrects/total)
        print('-' * 10)
        print('train: Loss: {:.4f} Acc: {:.4f}'.format(
            epoch_loss, epoch_acc))
        
        running_loss = 0.0
        corrects = 0.0
        total = 0.0
        for i, data in enumerate(testloader, 0):
            inputs = data[0].to(device)
            labels = data[1].to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            total += labels.size(0)
            corrects += (preds == labels).sum().item()  

        epoch_loss = running_loss / i
        epoch_acc = 100*corrects/total
        test_loss.append(epoch_loss)
        test_acc.append(epoch_acc)

        print('test:  Loss: {:.4f} Acc: {:.4f}'.format(
        epoch_loss, epoch_acc))
        print('-' * 10,'\n')

# %%
x_axis = range(1,num_epochs+1)

#plot loss
plt.plot(x_axis,train_loss,'blue')
plt.plot(x_axis,test_loss,'crimson') 
plt.legend(('train', 'test'),loc='upper right')
plt.title('customized CNN')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

#plot accuracy
plt.plot(x_axis,train_acc,'blue')
plt.plot(x_axis,test_acc,'crimson')
plt.legend(('train', 'test'),loc='upper left')
plt.title('customized CNN')
plt.xlabel('epoch')
plt.ylabel('accurarcy')
plt.show()
